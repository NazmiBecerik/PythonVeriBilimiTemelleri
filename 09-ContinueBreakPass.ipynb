# %%
benimListem=[5,10,15,20,25,30]

# %%
for numara in benimListem:
    if numara ==15:
        break
    print(numara)
# Out:
# 5
# 10

# %%
for numara in benimListem:
    if numara ==15:
        continue
    print(numara)
# Out:
# 5
# 10
# 20
# 25
# 30

# %%
for numara in benimListem:
    pass

# %%
# Yukarıda ki satır pass özelliğini açıklamıştır kod satırında bulundurmak ama işlem yaptırmamak içindir.
