# %% [markdown]
# ## PYTHON ÖĞRENİYORUM

# %% [markdown]
# ## Variables (DEĞİŞKENLER)

# %%
x=5

# %%
y=4

# %%
3*x*y
# Out:
# 60

# %% [markdown]
# ## Integer & Float

# %%
benimDegiskenim=10
benimdigerDegiskenim=20

# %%
benimDegiskenim+benimdigerDegiskenim
# Out:
# 30

# %%
type(benimDegiskenim)
# Out:
# int

# %%
sonuc=benimdigerDegiskenim/benimDegiskenim

# %%
sonuc
# Out:
# 2.0

# %%
type(sonuc)
# Out:
# float

# %%
pi=3.14

# %%
type(pi)
# Out:
# float

# %%
a=5

# %%
type(a)
# Out:
# int

# %%
pi*a
# Out:
# 15.700000000000001

# %%
a+pi
# Out:
# 8.14

# %%
a/pi
# Out:
# 1.592356687898089

# %%
a=5

# %%
b=4

# %%
sonuc=a*b

# %%
type(sonuc)
# Out:
# int

# %% [markdown]
# # MATEMATİKSEL İŞLEMLER

# %%
x=5

# %%
y=3

# %%
x*3
# Out:
# 15

# %%
x**3
# Out:
# 125

# %% [markdown]
# ##Kalanını Bulmak
# 11%2

# %%
kullaniciYasi = input("Yaşınızı Giriniz:")
# Out:
# Yaşınızı Giriniz:40

# %%
kullaniciYasi
# Out:
# '40'

# %%
kullaniciYasi*5
# Out:
# '4040404040'

# %% [markdown]
# ## STRİNG

# %%
"Merhaba Dünya"
# Out:
# 'Merhaba Dünya'

# %%
x="Merhaba Dünya"

# %%
y="Pyhton Öğreniyorum"

# %%
x+y
# Out:
# 'Merhaba DünyaPyhton Öğreniyorum'

# %%
y="yeni String"

# %%
benimString="Atıl Samancıoğlu"

# %% [markdown]
# $$ HATA        ALIYORUM $$

# %%
benimInput = input("Yaşınızı Giriniz:")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-06083177e8ca> in <module>
# ----> 1 benimInput = input("Yaşınızı Giriniz:")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## DEVAMI DİĞER SAYFADA ARTIK ##
