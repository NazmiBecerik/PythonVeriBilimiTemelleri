# %%
import numpy as np
import pandas as pd

# %%
data=np.random.randn(4,3)

# %%
data
# Out:
# array([[-0.41542245, -0.8257743 ,  0.05372474],
#        [ 0.39912927,  0.3774129 , -0.71380473],
#        [ 1.79111706,  1.12563438,  1.41992159],
#        [ 0.92127431,  0.50936691, -0.81039581]])

# %%
pd.DataFrame(data)
# Out:
#           0         1         2
# 0 -0.415422 -0.825774  0.053725
# 1  0.399129  0.377413 -0.713805
# 2  1.791117  1.125634  1.419922
# 3  0.921274  0.509367 -0.810396

# %%
yeniData=pd.DataFrame(data,index=["atil","esra","zeynep","mehmet"],columns=["maas","yas","cs"])

# %%
yeniData
# Out:
#             maas       yas        cs
# atil   -0.415422 -0.825774  0.053725
# esra    0.399129  0.377413 -0.713805
# zeynep  1.791117  1.125634  1.419922
# mehmet  0.921274  0.509367 -0.810396

# %%
yeniData.loc["atil"]
# Out:
# maas   -0.415422
# yas    -0.825774
# cs      0.053725
# Name: atil, dtype: float64

# %%
yeniData.iloc[0]
# Out:
# maas   -0.415422
# yas    -0.825774
# cs      0.053725
# Name: atil, dtype: float64

# %%
yeniData["emeklilik yasi"]=yeniData["yas"]+yeniData["yas"]

# %%
yeniData
# Out:
#             maas       yas        cs  emeklilik yasi
# atil   -0.415422 -0.825774  0.053725       -1.651549
# esra    0.399129  0.377413 -0.713805        0.754826
# zeynep  1.791117  1.125634  1.419922        2.251269
# mehmet  0.921274  0.509367 -0.810396        1.018734

# %%
yeniData.drop("emeklilik yasi",axis=1)
# Out:
#             maas       yas        cs
# atil   -0.415422 -0.825774  0.053725
# esra    0.399129  0.377413 -0.713805
# zeynep  1.791117  1.125634  1.419922
# mehmet  0.921274  0.509367 -0.810396

# %%
# axcis x veya y anlamına gelir eksen demektir.

# %%
yeniData.drop("mehmet")
# Out:
#             maas       yas        cs  emeklilik yasi
# atil   -0.415422 -0.825774  0.053725       -1.651549
# esra    0.399129  0.377413 -0.713805        0.754826
# zeynep  1.791117  1.125634  1.419922        2.251269

# %%
# eksenel olarak dropta öncelik x eksenindedir

# %%
# 6.28 ' de kaldım.

# %%
yeniData.loc["atil"]["maas"]
# Out:
# -0.41542245154502405

# %%
yeniData
# Out:
#             maas       yas        cs  emeklilik yasi
# atil   -0.415422 -0.825774  0.053725       -1.651549
# esra    0.399129  0.377413 -0.713805        0.754826
# zeynep  1.791117  1.125634  1.419922        2.251269
# mehmet  0.921274  0.509367 -0.810396        1.018734

# %%
yeniData<0
# Out:
#          maas    yas     cs  emeklilik yasi
# atil     True   True  False            True
# esra    False  False   True           False
# zeynep  False  False  False           False
# mehmet  False  False   True           False

# %%
yeniData[yeniData["maas"]<0]
# Out:
#           maas       yas        cs  emeklilik yasi
# atil -0.415422 -0.825774  0.053725       -1.651549

# %% [markdown]
# ## İNDEX DEĞİŞTİRME

# %%
# YANİ Y EKSENİN DE YAZILI OLANLARA İNDEX DİYORUZ VE İSİMLERİNİ DEĞİŞTİRECEĞİZ

# %%
yeniData
# Out:
#             maas       yas        cs  emeklilik yasi
# atil   -0.415422 -0.825774  0.053725       -1.651549
# esra    0.399129  0.377413 -0.713805        0.754826
# zeynep  1.791117  1.125634  1.419922        2.251269
# mehmet  0.921274  0.509367 -0.810396        1.018734

# %%
yeniData.reset_index()
# Out:
#     index      maas       yas        cs  emeklilik yasi
# 0    atil -0.415422 -0.825774  0.053725       -1.651549
# 1    esra  0.399129  0.377413 -0.713805        0.754826
# 2  zeynep  1.791117  1.125634  1.419922        2.251269
# 3  mehmet  0.921274  0.509367 -0.810396        1.018734

# %%
 yeniDatayeniListem=["zey","ati","naz","fey"]

# %%
yeniData["üc harfli isim"]=yeniDatayeniListem

# %%
yeniData
# Out:
#             maas       yas        cs  emeklilik yasi üc harfli isim
# atil   -0.415422 -0.825774  0.053725       -1.651549            zey
# esra    0.399129  0.377413 -0.713805        0.754826            ati
# zeynep  1.791117  1.125634  1.419922        2.251269            naz
# mehmet  0.921274  0.509367 -0.810396        1.018734            fey

# %%
yeniData.drop("üc harfli isim",axis=1)
# Out:
#             maas       yas        cs  emeklilik yasi
# atil   -0.415422 -0.825774  0.053725       -1.651549
# esra    0.399129  0.377413 -0.713805        0.754826
# zeynep  1.791117  1.125634  1.419922        2.251269
# mehmet  0.921274  0.509367 -0.810396        1.018734

# %%
yeniDataFrame=pd.DataFrame(yeniData)

# %%
yeniDataFrame
# Out:
#             maas       yas        cs  emeklilik yasi üc harfli isim
# atil   -0.415422 -0.825774  0.053725       -1.651549            zey
# esra    0.399129  0.377413 -0.713805        0.754826            ati
# zeynep  1.791117  1.125634  1.419922        2.251269            naz
# mehmet  0.921274  0.509367 -0.810396        1.018734            fey

# %%
IlkIndeksler=["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
IcIndeksler=["Homer","Bart","Marge","Cartmen","Kenny","Kyle"]

# %%
birlesmisIndeks=list(zip(IlkIndeksler,IcIndeksler))

# %%
birlesmisIndeks
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartmen'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
MultiIndeks=pd.MultiIndex.from_tuples(birlesmisIndeks)

# %%
MultiIndeks
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartmen'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
benimCizgiFilmListem=[[40,"A"],[30,"B"],[20,"C"],[40,"D"],[50,"E"],[60,"F"]]

# %%
benimCizgiFilmListem
# Out:
# [[40, 'A'], [30, 'B'], [20, 'C'], [40, 'D'], [50, 'E'], [60, 'F']]

# %%
CizgiFilmNupyDizisi=np.array(benimCizgiFilmListem)

# %%
CizgiFilmNupyDizisi
# Out:
# array([['40', 'A'],
#        ['30', 'B'],
#        ['20', 'C'],
#        ['40', 'D'],
#        ['50', 'E'],
#        ['60', 'F']], dtype='<U11')

# %%
CizgiFilmDataFrame=pd.DataFrame(CizgiFilmNupyDizisi,index=MultiIndeks,columns=["YAS","MESLEK"])

# %%
CizgiFilmDataFrame
# Out:
#                    YAS MESLEK
# Simpson    Homer    40      A
#            Bart     30      B
#            Marge    20      C
# South Park Cartmen  40      D
#            Kenny    50      E
#            Kyle     60      F

# %%
CizgiFilmDataFrame.loc["Simpson"]
# Out:
#       YAS MESLEK
# Homer  40      A
# Bart   30      B
# Marge  20      C

# %%
CizgiFilmDataFrame.loc["Simpson"].loc["Homer"]
# Out:
# YAS       40
# MESLEK     A
# Name: Homer, dtype: object

# %%
CizgiFilmDataFrame.index.names="Film Adı","Isim"

# %%
CizgiFilmDataFrame
# Out:
#                    YAS MESLEK
# Film Adı   Isim
# Simpson    Homer    40      A
#            Bart     30      B
#            Marge    20      C
# South Park Cartmen  40      D
#            Kenny    50      E
#            Kyle     60      F
