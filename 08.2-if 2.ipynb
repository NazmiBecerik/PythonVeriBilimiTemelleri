# %%
benimKahramanim=input("Kahramanınızı Seçiniz:")
# Out:
# Kahramanınızı Seçiniz:Nazmi

# %%
if benimKahramanim =="Batman":
    print("Doğru Seçim Yaşasın Yarasalar")
elif benimKahramanim == "Superman":
    print("Doğru Seçim Yaşasın Superman")
elif benimKahramanim =="Örümcek Adam":
    print("Doğru Seçim Yaşasın Örümcek Adam")
elif benimKahramanim == "Feyza":
    print("O yalnızca benim , yanlış seçim EVLAT")
else :
    print("Bu Kim Bilmiyorum")
# Out:
# Bu Kim Bilmiyorum

# %%
benimString= "nazmi Becerik"

# %%
benimString
# Out:
# 'nazmi Becerik'

# %%
if "Becerik" in benimString:
    print("Varmış")
else:
    print("Yokmuş")
# Out:
# Varmış

# %%
if benimString == "Nazmi Becerik":
    print("Eşit")
else:
    print("Eşit Değil")
# Out:
# Eşit Değil

# %%
BenimListem=[10,20,30,40,]

# %%
type(BenimListem)
# Out:
# list

# %%
if 50 in BenimListem:
    print("Listenizde bu sayı bulunmakta")
else :
    print("Listenizde bu sayı bulunmamakta")
# Out:
# Listenizde bu sayı bulunmamakta

# %%
benimSozluk={"muz":100,"elma":120,"armut":75}

# %%
type(benimSozluk)
# Out:
# dict

# %%
if "muz" in benimSozluk.keys():
    print("Yer Almakta")
else :
    print("Yer Almamaktadır")
# Out:
# Yer Almakta

# %%
if 75 in benimSozluk.values():
    print("Yer Almakta.")
else:
    print("Yer Almamaktadır.")
# Out:
# Yer Almakta.
