# %%
if 3>4 :
    print("Sadece if geçerli ise çalışır")
    print("Bu kod bloğundan backspace ile çıkarsak")
    print("Diğer altta yazanlar çalışmaz")
print("backspace ile if karar yapısının dışına çıktık ve true olmadığı halde bunu yazabiliriz")
# Out:
# backspace ile if karar yapısının dışına çıktık ve true olmadığı halde bunu yazabiliriz

# %%
x=3
y=4

# %%
if x>y :
    print("x y'den büyükmüş")
else  :
    print ("x y'den küçükmüş")
# Out:
# x y'den küçükmüş

# %%
x=4
y=4

# %%
if x>y :
    print("x büyüktür y'den")
elif x==y:
    print("x eşittir y'ye")
else:
    print("y büyüktür x'e")
