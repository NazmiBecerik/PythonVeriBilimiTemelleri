# %%
benimBoolean=True

# %%
type(benimBoolean)
# Out:
# bool

# %%
benimBoolean
# Out:
# True

# %%
benimDigerBoolean=False

# %%
10<5
# Out:
# False

# %%
5<10
# Out:
# True

# %%
Listem=[1000,2000,10000,30000]

# %%
Listem
# Out:
# [1000, 2000, 10000, 30000]

# %%
len(Listem)
# Out:
# 4

# %%
sum(Listem)
# Out:
# 43000

# %%
ortalama=sum(Listem)/len(Listem)

# %%
ortalama
# Out:
# 10750.0
