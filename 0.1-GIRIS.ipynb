# %%
benimInput=input("Yaşınızı Giriniz:")
# Out:
# Yaşınızı Giriniz:21

# %%
type(benimInput)
# Out:
# str

# %%
benimIntInput=int(benimInput)

# %%
benimIntInput/3*5
# Out:
# 35.0

# %%
k="Atıl Samancıoğlu"

# %%
len(k)
# Out:
# 16

# %%
print("Merhaba \nPyhton")
# Out:
# Merhaba
# Pyhton

# %%
isimString="Nazmi Becerik"

# %%
isimString
# Out:
# 'Nazmi Becerik'

# %% [markdown]
# İNDEXLEME

# %%
isimString[0]
# Out:
# 'N'

# %%
isimString[9]
# Out:
# 'e'

# %%
isimString[-1]
# Out:
# 'k'

# %%
isimString[3-5]
# Out:
# 'i'

# %%
yenistring="0123456789"

# %%
yenistring[0]
# Out:
# '0'

# %%
yenistring[2:]
# Out:
# '23456789'

# %%
yenistring[:3]
# Out:
# '012'

# %% [markdown]
# # SLİCİNG

# %%
gelenveri="AhmetinYasi65"

# %%
gelenveri[-2:]
# Out:
# '65'

# %%
gelenveri[:2]
# Out:
# 'Ah'

# %%
##STEPSİZE

# %%
gelenveri[1:10:2]
# Out:
# 'heiYs'

# %%
## birinci start ikinci stop üçüncü aralık belirleme.

# %%
gelenveri[::-1]
# Out:
# '56isaYnitemhA'

# %%
benimIsmim="atıl"

# %%
benimIsmim.capitalize()
# Out:
# 'Atıl'

# %%
benimTamIsmim="Nazmi Becerik"

# %%
benimTamIsmim.split()
# Out:
# ['Nazmi', 'Becerik']

# %%
type(benimTamIsmim.split())
# Out:
# list

# %%
benimTamIsmim.upper()
# Out:
# 'NAZMI BECERIK'
