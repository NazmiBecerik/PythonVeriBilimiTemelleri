# %%
benimString="Atıl Samancıoğlu"

# %%
benimString[0]
# Out:
# 'A'

# %%
##İmmutability değişmezlik manasına gelir.

# %%
#benimString[0]="b"

# %%
benimListem=[10,20,30,40]

# %%
type(benimListem)
# Out:
# list

# %%
benimNumaram=10
benimDigerNumaram=20

# %%
benimNumaraListem=[benimNumaram,benimDigerNumaram]

# %%
benimListem[0]
# Out:
# 10

# %%
benimNumaraListem[0]
# Out:
# 10

# %%
benimListem[0]=100

# %%
benimListem
# Out:
# [10, 20, 30, 40]

# %%
benimListem.append(50)

# %%
benimListem
# Out:
# [10, 20, 30, 40, 50]

# %%
benimListem.pop()
# Out:
# 50

# %%
benimListem.remove(40)

# %%
benimListem
# Out:
# [100, 20, 30]

# %%
benimListem.append(20)

# %%
benimListem
# Out:
# [100, 20, 30, 20]

# %%
benimListem.count(20)
# Out:
# 2

# %%
benimStringListem="Atıl","Ahmet","Zeynep"

# %%
benimDigerStringListem="Mehmet","Nazmi","Selçuk","Havva"

# %%
benimStringListem[2]
# Out:
# 'Zeynep'

# %%
benimDigerStringListem[3]
# Out:
# 'Havva'

# %%
benimToplamaListem=benimStringListem+benimDigerStringListem

# %%
benimToplamaListem
# Out:
# ('Atıl', 'Ahmet', 'Zeynep', 'Mehmet', 'Nazmi', 'Selçuk', 'Havva')

# %%
benimToplamaListem
# Out:
# ('Atıl', 'Ahmet', 'Zeynep', 'Mehmet', 'Nazmi', 'Selçuk', 'Havva')

# %%
nestedList=[1,5,"Atıl",[6,"z"]]

# %%
istekList=nestedList[3][1]

# %%
istekList
# Out:
# 'z'

# %%
karmasikListe=[[1,2,3,["a","b"],50],40,20,["z",5.5],[3,["a"]]]

# %%
istenenb=karmasikListe[0][3][1]

# %%
istenenb
# Out:
# 'b'
