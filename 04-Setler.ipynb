# %%
benimListem=[1,2,3,1,2,3]

# %% [markdown]
# ## listede eleman tekrarlı olarak kullanılabilir ama set sadece 1 defa kullanır.

# %%
benimListeSetim=set(benimListem)

# %%
type(benimListem)
# Out:
# list

# %%
type(benimListeSetim)
# Out:
# set

# %%
benimListeSetim
# Out:
# {1, 2, 3}

# %%
benimset={"a","b","c","a"}

# %%
benimset
# Out:
# {'a', 'b', 'c'}
