# %%
import numpy as np
import pandas as pd

# %%
benimSozlugum={"Nazmi":21,"Feyza":21,"Esra":21}

# %%
pd.Series(benimSozlugum)
# Out:
# Nazmi    21
# Feyza    21
# Esra     21
# dtype: int64

# %%
benimIsimlerim=["Nazmi","Feyza","Esra"]

# %%
benimYaslarim=[21,21,21]

# %%
pd.Series(benimYaslarim,benimIsimlerim)
# Out:
# Nazmi    21
# Feyza    21
# Esra     21
# dtype: int64

# %%
numpyDizisi=np.array(benimYaslarim)

# %%
numpyDizisi
# Out:
# array([21, 21, 21])

# %%
pd.Series(numpyDizisi,benimIsimlerim)
# Out:
# Nazmi    21
# Feyza    21
# Esra     21
# dtype: int32

# %%
YarismaSonucu=pd.Series(["Nazmi","Feyza","Esra"],[3,1,2])

# %%
YarismaSonucu
# Out:
# 3    Nazmi
# 1    Feyza
# 2     Esra
# dtype: object

# %%
puanDurumu1=pd.Series([10,20],["Nazmi","Feyza"])

# %%
puanDurumu2=pd.Series([10,30],["Nazmi","Feyza"])

# %%
puanDurumu1
# Out:
# Nazmi    10
# Feyza    20
# dtype: int64

# %%
puanDurumu2
# Out:
# Nazmi    10
# Feyza    30
# dtype: int64

# %%
sonPuanDurumu=puanDurumu1+puanDurumu2

# %%
sonPuanDurumu
# Out:
# Nazmi    20
# Feyza    50
# dtype: int64

# %%
sonPuanDurumu["Nazmi"]
# Out:
# 20

# %%
sonPuanDurumu["Feyza"]
# Out:
# 50
