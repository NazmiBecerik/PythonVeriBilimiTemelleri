# %%
benimListem=[1,2,3]

# %%
benimListem[0]
# Out:
# 1

# %% [markdown]
# ## KEY VALUE PARİNG (ANAHTAR KELİME VE DEĞER EŞLEŞMESİ)

# %%
benimYemeklerim=["elma","muz","armut"]

# %%
benimKalorilerim=[100,200,300]

# %%
benimYemeklerim[1]
# Out:
# 'muz'

# %%
benimKalorilerim[1]
# Out:
# 200

# %%
benimSozluk={"Anahtar Kelime" : "Değeri"}

# %%
type(benimSozluk)
# Out:
# dict

# %%
benimYemekKaloriSozlugum={"muz" : 100 , "elma" : 150 , "kivi" : 300}

# %%
benimYemekKaloriSozlugum["muz"]
# Out:
# 100

# %%
yenidictionary={"anahtar1":100,"anahtar2":[10,20,30,40,4.5,"atıl"],"anahtar3":{"anahtar9":4}}

# %%
yenidictionary["anahtar2"][5]
# Out:
# 'atıl'

# %%
yenidictionary["anahtar3"]["anahtar9"]
# Out:
# 4
